# %%
from Image_generation import train_GAN, train_WGAN, generate_images

# %%
generator, discriminator = train_GAN(epochs=30)
# Out:
# Epoch 1/30 | D Loss: 0.5305 | G Loss: 2.3346
# Epoch 2/30 | D Loss: 0.6217 | G Loss: 1.1227
# Epoch 3/30 | D Loss: 0.5157 | G Loss: 2.0992
# Epoch 4/30 | D Loss: 0.4061 | G Loss: 2.3553
# Epoch 5/30 | D Loss: 0.6044 | G Loss: 1.6518
# Epoch 6/30 | D Loss: 0.5514 | G Loss: 1.8606
# Epoch 7/30 | D Loss: 0.4291 | G Loss: 2.4472
# Epoch 8/30 | D Loss: 0.4294 | G Loss: 1.5301
# Epoch 9/30 | D Loss: 0.7276 | G Loss: 0.9224
# Epoch 10/30 | D Loss: 0.5793 | G Loss: 0.8820
# Epoch 11/30 | D Loss: 0.5128 | G Loss: 1.0019
# Epoch 12/30 | D Loss: 0.4754 | G Loss: 1.3679
# Epoch 13/30 | D Loss: 0.6664 | G Loss: 0.6756
# Epoch 14/30 | D Loss: 0.9093 | G Loss: 2.2554
# Epoch 15/30 | D Loss: 0.7337 | G Loss: 0.5229
# Epoch 16/30 | D Loss: 0.3934 | G Loss: 1.5784
# Epoch 17/30 | D Loss: 0.4472 | G Loss: 1.5255
# Epoch 18/30 | D Loss: 0.4723 | G Loss: 2.3208
# Epoch 19/30 | D Loss: 0.6356 | G Loss: 0.8641
# Epoch 20/30 | D Loss: 0.5084 | G Loss: 1.9586
# Epoch 21/30 | D Loss: 0.4390 | G Loss: 0.9861
# ...

# %%
generate_images(generator)
